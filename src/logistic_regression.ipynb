# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../dataset/dry_bean.csv")

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
glr = GridSearchCV(LogisticRegression(), param_grid={
    "penalty": ["elasticnet", "l1", "l2"],
    "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "solver": ["lbfgs", "liblinear", "newton-cg", "newton-cholesky", "sag", "saga"],
    "multi_class": ["ovr"]
}, scoring="accuracy", cv=5, verbose=0)

# %%
glr.fit(X_train, y_train)
# Out:
# /home/vin/Documents/assignments/computational-intelligence/computational-intelligence-week-5/venv/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/vin/Documents/assignments/computational-intelligence/computational-intelligence-week-5/venv/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/vin/Documents/assignments/computational-intelligence/computational-intelligence-week-5/venv/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
glr.best_params_
# Out:
# {'C': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cholesky'}

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score

# %%
y_pred = glr.predict(X_test)

# %%
result = classification_report(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9250826294528094

# %%
print(result)
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.97      0.89      0.93       288
#       BOMBAY       1.00      1.00      1.00       106
#         CALI       0.94      0.95      0.94       308
#     DERMASON       0.91      0.93      0.92       685
#        HOROZ       0.96      0.94      0.95       380
#        SEKER       0.96      0.94      0.95       412
#         SIRA       0.85      0.88      0.87       544
#
#     accuracy                           0.93      2723
#    macro avg       0.94      0.93      0.94      2723
# weighted avg       0.93      0.93      0.93      2723

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(confusion_matrix(y_test, y_pred), fmt=" ", annot=True, linewidths=0.5)
plt.show()

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[256,   0,  14,   0,   1,   4,  13],
#        [  0, 106,   0,   0,   0,   0,   0],
#        [  7,   0, 293,   0,   5,   0,   3],
#        [  0,   0,   0, 638,   0,   7,  40],
#        [  0,   0,   5,   5, 358,   0,  12],
#        [  2,   0,   0,   5,   0, 389,  16],
#        [  0,   0,   1,  51,   8,   5, 479]])

# %%
precision_score(y_test, y_pred, average="micro")
# Out:
# 0.9250826294528094

# %%
recall_score(y_test, y_pred, average="micro")
# Out:
# 0.9250826294528094

# %%
precision_score(y_test, y_pred, average="macro")
# Out:
# 0.941218736473398

# %%
recall_score(y_test, y_pred, average="macro")
# Out:
# 0.9340527396890371

# %%
from sklearn.inspection import DecisionBoundaryDisplay
